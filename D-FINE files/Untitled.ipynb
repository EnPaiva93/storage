# %%
from datasets import load_dataset

PATH_IMGS = "DocSynth300K/part{i}.parquet"

dict_train = {
    'train': [PATH_IMGS.format(i=part) for part in range(6)]
}

# %%
dataset = load_dataset("parquet", data_files=dict_train)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset["train"]
# Out:
# Dataset({
#     features: ['filename', 'image_data', 'anno_string'],
#     num_rows: 60000
# })

# %%
dataset["train"][0]["anno_string"]
# Out:
# ['23 0.09418776004975932 0.5595031058841483 0.7866484741599264 0.5595031058841483 0.7866484741599264 0.6310490192911521 0.09418776004975932 0.6310490192911521\n',
#  '23 0.025344482243170985 0.6790733584791682 0.841925510585198 0.6790733584791682 0.841925510585198 0.9578693857758978 0.025344482243170985 0.9578693857758978\n',
#  '48 0.881509062476827 0.5635644737323318 0.9857609303515421 0.5635644737323318 0.9857609303515421 0.6432671603123155 0.881509062476827 0.6432671603123155\n',
#  '23 0.17098698433273263 0.07759363984136039 0.7090846649951416 0.07759363984136039 0.7090846649951416 0.47601573134394237 0.17098698433273263 0.47601573134394237\n',
#  '48 0.8915939033032338 0.5259971478922201 0.9756760895251353 0.5259971478922201 0.9756760895251353 0.5530343195455241 0.8915939033032338 0.5530343195455241\n',
#  '56 0.8772106127392312 0.006229576679376184 0.990059380089138 0.006229576679376184 0.990059380089138 0.025535426077934683 0.8772106127392312 0.025535426077934683\n',
# ...

# %%
image_index = 0

row = dataset["train"][image_index]

filename = row['filename']
image_data = row['image_data']
anno_string = row['anno_string']

image = Image.open(io.BytesIO(image_data))
